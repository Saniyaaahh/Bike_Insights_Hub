# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r"/content/bikes_data.csv")

# %%
data
# Out:
#                     Company Country of Origin           Model Number of cc  \
# 0                   Aprilia             Italy          RS 660          659
# 1                   Aprilia             Italy       Tuono 660          659
# 2                   Aprilia             Italy          RS 125        124.9
# 3                   Aprilia             Italy      Shiver 900          896
# 4                   Aprilia             Italy      Tuono 1100         1077
# ..                      ...               ...             ...          ...
# 357  Energica Motor Company             Italy       EsseEsse9       110 kW
# 358  Energica Motor Company             Italy            EGO+       126 kW
# 359  Energica Motor Company             Italy  Eva Ribelle RS       126 kW
# 360             Moto Morini             Italy          X-Cape          649
# 361             Moto Morini             Italy  Seiemmezzo 6 ½          649
#
#     Horsepower     Torque     Transmission Type     Drivetrain  \
# ...

# %%
data.head()
# Out:
#    Company Country of Origin       Model Number of cc Horsepower  Torque  \
# 0  Aprilia             Italy      RS 660          659     100 hp   67 Nm
# 1  Aprilia             Italy   Tuono 660          659     100 hp   67 Nm
# 2  Aprilia             Italy      RS 125        124.9      15 hp   12 Nm
# 3  Aprilia             Italy  Shiver 900          896      95 hp   90 Nm
# 4  Aprilia             Italy  Tuono 1100         1077     175 hp  121 Nm
#
#       Transmission Type Drivetrain  Number of Seating Price (in INR)  Year  \
# 0  6-speed quickshifter      Chain                  2  INR 10,99,000  2021
# 1  6-speed quickshifter      Chain                  2  INR 11,99,000  2021
# 2        6-speed manual      Chain                  2   INR 4,49,000  2022
# 3        6-speed manual      Shaft                  2  INR 13,99,000  2022
# 4        6-speed manual      Shaft                  2  INR 19,99,000  2022
#
#        Looks Body Type      Engine Type Number of Cylinders
# ...

# %%
data.describe()
# Out:
#        Number of Seating         Year
# count         362.000000   362.000000
# mean            1.618785  2021.627072
# std             0.492020     3.691967
# min             1.000000  1994.000000
# 25%             1.000000  2022.000000
# 50%             2.000000  2023.000000
# 75%             2.000000  2023.000000
# max             3.000000  2023.000000

# %%
data.dtypes
# Out:
# Company                object
# Country of Origin      object
# Model                  object
# Number of cc           object
# Horsepower             object
# Torque                 object
# Transmission Type      object
# Drivetrain             object
# Number of Seating       int64
# Price (in INR)         object
# Year                    int64
# Looks                  object
# Body Type              object
# Engine Type            object
# Number of Cylinders    object
# dtype: object

# %%
data.columns=data.columns.str.replace(' ','_')

# %%
data
# Out:
#                     Company Country_of_Origin           Model Number_of_cc  \
# 0                   Aprilia             Italy          RS 660          659
# 1                   Aprilia             Italy       Tuono 660          659
# 2                   Aprilia             Italy          RS 125        124.9
# 3                   Aprilia             Italy      Shiver 900          896
# 4                   Aprilia             Italy      Tuono 1100         1077
# ..                      ...               ...             ...          ...
# 357  Energica Motor Company             Italy       EsseEsse9       110 kW
# 358  Energica Motor Company             Italy            EGO+       126 kW
# 359  Energica Motor Company             Italy  Eva Ribelle RS       126 kW
# 360             Moto Morini             Italy          X-Cape          649
# 361             Moto Morini             Italy  Seiemmezzo 6 ½          649
#
#     Horsepower     Torque     Transmission_Type     Drivetrain  \
# ...

# %%
data.count()
# Out:
# Company                362
# Country_of_Origin      362
# Model                  362
# Number_of_cc           362
# Horsepower             362
# Torque                 362
# Transmission_Type      362
# Drivetrain             362
# Number_of_Seating      362
# Price_(in_INR)         362
# Year                   362
# Looks                  362
# Body_Type              362
# Engine_Type            362
# Number_of_Cylinders    361
# dtype: int64

# %%
data['Company'].value_counts()
# Out:
# Benelli             16
# Husqvarna           12
# Mutt Motorcycles    11
# KTM                  9
# Genuine Scooters     9
#                     ..
# Italjet              1
# Derbi                1
# Ontrack              1
# Ampere               1
# Fantic               1
# Name: Company, Length: 75, dtype: int64

# %%
data['Country_of_Origin'].value_counts()
# Out:
# Italy             92
# India             47
# China             44
# UK                28
# Japan             24
# United States     19
# Taiwan            18
# United Kingdom    17
# Austria           14
# USA               13
# Sweden            12
# Spain              9
# Germany            8
# France             8
# South Korea        5
# Canada             3
# Denmark            1
# Name: Country_of_Origin, dtype: int64

# %%
data['Model'].value_counts()
# Out:
# Artemis           4
# TC                2
# Svartpilen 401    2
# X-Cape            2
# Seiemmezzo 6 ½    2
#                  ..
# MGX-21            1
# Eldorado          1
# Audace            1
# V9 Roamer         1
# Eva Ribelle RS    1
# Name: Model, Length: 345, dtype: int64

# %%
data['Number_of_cc'].value_counts()
# Out:
# 125     60
# 250     24
# 300     12
# 500      8
# 110      7
#         ..
# 1133     1
# 693      1
# 1158     1
# 321      1
# 346      1
# Name: Number_of_cc, Length: 139, dtype: int64

# %%
data['Number_of_cc'] = pd.to_numeric(data['Number_of_cc'], errors='coerce').fillna(0).round().astype(int)

# %%
data
# Out:
#                     Company Country_of_Origin           Model  Number_of_cc  \
# 0                   Aprilia             Italy          RS 660           659
# 1                   Aprilia             Italy       Tuono 660           659
# 2                   Aprilia             Italy          RS 125           125
# 3                   Aprilia             Italy      Shiver 900           896
# 4                   Aprilia             Italy      Tuono 1100          1077
# ..                      ...               ...             ...           ...
# 357  Energica Motor Company             Italy       EsseEsse9             0
# 358  Energica Motor Company             Italy            EGO+             0
# 359  Energica Motor Company             Italy  Eva Ribelle RS             0
# 360             Moto Morini             Italy          X-Cape           649
# 361             Moto Morini             Italy  Seiemmezzo 6 ½           649
#
# ...

# %%
data['Horsepower'].value_counts()
# Out:
# 11 hp                  6
# 20 bhp                 6
# 95 hp                  5
# 15 hp                  5
# 18.4 bhp               5
#                       ..
# 26.5 hp @ 8,500 rpm    1
# 38 hp                  1
# 24 hp                  1
# 94                     1
# 42 hp                  1
# Name: Horsepower, Length: 245, dtype: int64

# %%
data['Horsepower'] = pd.to_numeric(data['Horsepower'].str.replace(' hp', ''), errors='coerce')

# %%
data
# Out:
#                     Company Country_of_Origin           Model  Number_of_cc  \
# 0                   Aprilia             Italy          RS 660           659
# 1                   Aprilia             Italy       Tuono 660           659
# 2                   Aprilia             Italy          RS 125           125
# 3                   Aprilia             Italy      Shiver 900           896
# 4                   Aprilia             Italy      Tuono 1100          1077
# ..                      ...               ...             ...           ...
# 357  Energica Motor Company             Italy       EsseEsse9             0
# 358  Energica Motor Company             Italy            EGO+             0
# 359  Energica Motor Company             Italy  Eva Ribelle RS             0
# 360             Moto Morini             Italy          X-Cape           649
# 361             Moto Morini             Italy  Seiemmezzo 6 ½           649
#
# ...

# %%
data['Torque'].value_counts()
# Out:
# 10.5 Nm               10
# 18 Nm                  9
# 10 Nm                  8
# 11 Nm                  6
# 12 Nm                  6
#                       ..
# 32 Nm@4250 rpm         1
# 52.3 Nm @ 5650 rpm     1
# 14 Nm @ 6000 rpm       1
# 163 lb-ft              1
# 58 Nm                  1
# Name: Torque, Length: 219, dtype: int64

# %%
data['Torque'] = pd.to_numeric(data['Torque'].str.replace('Nm',''), errors='coerce')

# %%
data
# Out:
#                     Company Country_of_Origin           Model  Number_of_cc  \
# 0                   Aprilia             Italy          RS 660           659
# 1                   Aprilia             Italy       Tuono 660           659
# 2                   Aprilia             Italy          RS 125           125
# 3                   Aprilia             Italy      Shiver 900           896
# 4                   Aprilia             Italy      Tuono 1100          1077
# ..                      ...               ...             ...           ...
# 357  Energica Motor Company             Italy       EsseEsse9             0
# 358  Energica Motor Company             Italy            EGO+             0
# 359  Energica Motor Company             Italy  Eva Ribelle RS             0
# 360             Moto Morini             Italy          X-Cape           649
# 361             Moto Morini             Italy  Seiemmezzo 6 ½           649
#
# ...

# %%
data['Transmission_Type'].value_counts()
# Out:
# 6-speed manual                  114
# Manual                           50
# CVT                              42
# Automatic                        36
# 5-speed manual                   27
# 6-speed Manual                    8
# Six-speed                         8
# 5-speed                           7
# Five-speed constant mesh          7
# 4-speed constant mesh             6
# 6-speed sequential                6
# Six-speed sequential              6
# Six-speed constant mesh           5
# 5-speed constant mesh             4
# 6-Speed                           4
# 6-speed automatic                 4
# 4-speed manual                    3
# CVT Automatic                     3
# 4-speed                           3
# 6 Speed Manual                    3
# BLDC hub motor                    2
# 6-speed sequential manual         2
# 6-speed quickshifter              2
# 6-speed constant mesh             2
# Direct drive                      1
# Single Speed                      1
# ...

# %%
top_transmissions = data['Transmission_Type'].value_counts().head(5).index

# %%
data.loc[~data['Transmission_Type'].isin(top_transmissions), 'Transmission_Type']='Others'

# %%
data
# Out:
#                     Company Country_of_Origin           Model  Number_of_cc  \
# 0                   Aprilia             Italy          RS 660           659
# 1                   Aprilia             Italy       Tuono 660           659
# 2                   Aprilia             Italy          RS 125           125
# 3                   Aprilia             Italy      Shiver 900           896
# 4                   Aprilia             Italy      Tuono 1100          1077
# ..                      ...               ...             ...           ...
# 357  Energica Motor Company             Italy       EsseEsse9             0
# 358  Energica Motor Company             Italy            EGO+             0
# 359  Energica Motor Company             Italy  Eva Ribelle RS             0
# 360             Moto Morini             Italy          X-Cape           649
# 361             Moto Morini             Italy  Seiemmezzo 6 ½           649
#
# ...

# %%
data['Transmission_Type'].value_counts()
# Out:
# 6-speed manual    114
# Others             93
# Manual             50
# CVT                42
# Automatic          36
# 5-speed manual     27
# Name: Transmission_Type, dtype: int64

# %%
data['Drivetrain'].value_counts()
# Out:
# Chain                                 110
# Chain drive                            93
# Automatic                              35
# Chain Drive                            22
# Belt drive                             20
# Electric                               16
# Shaft drive                            16
# CVT                                    15
# Shaft                                  11
# Belt                                    4
# Shimano drivetrain                      4
# Automatic CVT                           3
# Front wheel drive                       3
# Belt Drive                              2
# Parallel twin                           2
# Permanent magnet synchronous motor      1
# Front Suspension                        1
# Single-gear                             1
# Dual-motor, all-wheel drive             1
# V-twin, liquid-cooled, 4-stroke         1
# Rear wheel                              1
# Name: Drivetrain, dtype: int64

# %%
top_drivetrain = data['Drivetrain'].value_counts().head(5).index

# %%
data.loc[~data['Drivetrain'].isin(top_drivetrain),'Drivetrain']='Others'

# %%
data
# Out:
#                     Company Country_of_Origin           Model  Number_of_cc  \
# 0                   Aprilia             Italy          RS 660           659
# 1                   Aprilia             Italy       Tuono 660           659
# 2                   Aprilia             Italy          RS 125           125
# 3                   Aprilia             Italy      Shiver 900           896
# 4                   Aprilia             Italy      Tuono 1100          1077
# ..                      ...               ...             ...           ...
# 357  Energica Motor Company             Italy       EsseEsse9             0
# 358  Energica Motor Company             Italy            EGO+             0
# 359  Energica Motor Company             Italy  Eva Ribelle RS             0
# 360             Moto Morini             Italy          X-Cape           649
# 361             Moto Morini             Italy  Seiemmezzo 6 ½           649
#
# ...

# %%
data['Drivetrain'].value_counts()
# Out:
# Chain          110
# Chain drive     93
# Others          82
# Automatic       35
# Chain Drive     22
# Belt drive      20
# Name: Drivetrain, dtype: int64

# %%
data['Number_of_Seating'].value_counts()
# Out:
# 2    222
# 1    139
# 3      1
# Name: Number_of_Seating, dtype: int64

# %%
data['Price_(in_INR)'] = data['Price_(in_INR)'].str.replace('INR','')

# %%
data
# Out:
#                     Company Country_of_Origin           Model  Number_of_cc  \
# 0                   Aprilia             Italy          RS 660           659
# 1                   Aprilia             Italy       Tuono 660           659
# 2                   Aprilia             Italy          RS 125           125
# 3                   Aprilia             Italy      Shiver 900           896
# 4                   Aprilia             Italy      Tuono 1100          1077
# ..                      ...               ...             ...           ...
# 357  Energica Motor Company             Italy       EsseEsse9             0
# 358  Energica Motor Company             Italy            EGO+             0
# 359  Energica Motor Company             Italy  Eva Ribelle RS             0
# 360             Moto Morini             Italy          X-Cape           649
# 361             Moto Morini             Italy  Seiemmezzo 6 ½           649
#
# ...

# %%
data['Price_(in_INR)'] = data['Price_(in_INR)'].str.replace('lakhs','')

# %%
data
# Out:
#                     Company Country_of_Origin           Model  Number_of_cc  \
# 0                   Aprilia             Italy          RS 660           659
# 1                   Aprilia             Italy       Tuono 660           659
# 2                   Aprilia             Italy          RS 125           125
# 3                   Aprilia             Italy      Shiver 900           896
# 4                   Aprilia             Italy      Tuono 1100          1077
# ..                      ...               ...             ...           ...
# 357  Energica Motor Company             Italy       EsseEsse9             0
# 358  Energica Motor Company             Italy            EGO+             0
# 359  Energica Motor Company             Italy  Eva Ribelle RS             0
# 360             Moto Morini             Italy          X-Cape           649
# 361             Moto Morini             Italy  Seiemmezzo 6 ½           649
#
# ...

# %%
data['Price_(in_INR)'] = data['Price_(in_INR)'].str.replace(',','')

# %%
data['Price_(in_INR)'] = pd.to_numeric(data['Price_(in_INR)'], errors='coerce')

# %%
data
# Out:
#                     Company Country_of_Origin           Model  Number_of_cc  \
# 0                   Aprilia             Italy          RS 660           659
# 1                   Aprilia             Italy       Tuono 660           659
# 2                   Aprilia             Italy          RS 125           125
# 3                   Aprilia             Italy      Shiver 900           896
# 4                   Aprilia             Italy      Tuono 1100          1077
# ..                      ...               ...             ...           ...
# 357  Energica Motor Company             Italy       EsseEsse9             0
# 358  Energica Motor Company             Italy            EGO+             0
# 359  Energica Motor Company             Italy  Eva Ribelle RS             0
# 360             Moto Morini             Italy          X-Cape           649
# 361             Moto Morini             Italy  Seiemmezzo 6 ½           649
#
# ...

# %%
def convert_price(price_str):
    if isinstance(price_str, (int, float)):
        return price_str
    if 'lakhs' in price_str:
        return int(float(price_str.split(' ')[0].replace(',', '')) * 100000)
    elif 'crores' in price_str:
        return int(float(price_str.split(' ')[0].replace(',', '')) * 10000000)
    else:
        return int(price_str.replace(',', ''))

# %%
data
# Out:
#                     Company Country_of_Origin           Model  Number_of_cc  \
# 0                   Aprilia             Italy          RS 660           659
# 1                   Aprilia             Italy       Tuono 660           659
# 2                   Aprilia             Italy          RS 125           125
# 3                   Aprilia             Italy      Shiver 900           896
# 4                   Aprilia             Italy      Tuono 1100          1077
# ..                      ...               ...             ...           ...
# 357  Energica Motor Company             Italy       EsseEsse9             0
# 358  Energica Motor Company             Italy            EGO+             0
# 359  Energica Motor Company             Italy  Eva Ribelle RS             0
# 360             Moto Morini             Italy          X-Cape           649
# 361             Moto Morini             Italy  Seiemmezzo 6 ½           649
#
# ...

# %%
data['Price_(in_INR)'] = data['Price_(in_INR)'].apply(convert_price)

# %%
data
# Out:
#                     Company Country_of_Origin           Model  Number_of_cc  \
# 0                   Aprilia             Italy          RS 660           659
# 1                   Aprilia             Italy       Tuono 660           659
# 2                   Aprilia             Italy          RS 125           125
# 3                   Aprilia             Italy      Shiver 900           896
# 4                   Aprilia             Italy      Tuono 1100          1077
# ..                      ...               ...             ...           ...
# 357  Energica Motor Company             Italy       EsseEsse9             0
# 358  Energica Motor Company             Italy            EGO+             0
# 359  Energica Motor Company             Italy  Eva Ribelle RS             0
# 360             Moto Morini             Italy          X-Cape           649
# 361             Moto Morini             Italy  Seiemmezzo 6 ½           649
#
# ...

# %%
top_looks = data['Looks'].value_counts().head(9).index

# %%
data.loc[~data['Looks'].isin(top_looks),'Looks']='Others'

# %%
data
# Out:
#                     Company Country_of_Origin           Model  Number_of_cc  \
# 0                   Aprilia             Italy          RS 660           659
# 1                   Aprilia             Italy       Tuono 660           659
# 2                   Aprilia             Italy          RS 125           125
# 3                   Aprilia             Italy      Shiver 900           896
# 4                   Aprilia             Italy      Tuono 1100          1077
# ..                      ...               ...             ...           ...
# 357  Energica Motor Company             Italy       EsseEsse9             0
# 358  Energica Motor Company             Italy            EGO+             0
# 359  Energica Motor Company             Italy  Eva Ribelle RS             0
# 360             Moto Morini             Italy          X-Cape           649
# 361             Moto Morini             Italy  Seiemmezzo 6 ½           649
#
# ...

# %%
data['Number_of_Cylinders'].value_counts()
# Out:
# 1                181
# 2                 66
# Single            65
# 3                 13
# 4                 11
# Two                9
# One                7
# 90°                6
# 0                  1
# Three              1
# Parallel-Twin      1
# Name: Number_of_Cylinders, dtype: int64

# %%
data['Number_of_Cylinders'] = data['Number_of_Cylinders'].replace({
    'One': '1',
    'Two': '2',
    'Three': '3',
    'Single':'1'
})

# %%
data['Number_of_Cylinders'] = pd.to_numeric(data['Number_of_Cylinders'], errors='coerce').fillna(0).astype(int)

# %%
data
# Out:
#                     Company Country_of_Origin           Model  Number_of_cc  \
# 0                   Aprilia             Italy          RS 660           659
# 1                   Aprilia             Italy       Tuono 660           659
# 2                   Aprilia             Italy          RS 125           125
# 3                   Aprilia             Italy      Shiver 900           896
# 4                   Aprilia             Italy      Tuono 1100          1077
# ..                      ...               ...             ...           ...
# 357  Energica Motor Company             Italy       EsseEsse9             0
# 358  Energica Motor Company             Italy            EGO+             0
# 359  Energica Motor Company             Italy  Eva Ribelle RS             0
# 360             Moto Morini             Italy          X-Cape           649
# 361             Moto Morini             Italy  Seiemmezzo 6 ½           649
#
# ...

# %%
data.head()
# Out:
#    Company Country_of_Origin       Model  Number_of_cc  Horsepower  Torque  \
# 0  Aprilia             Italy      RS 660           659       100.0    67.0
# 1  Aprilia             Italy   Tuono 660           659       100.0    67.0
# 2  Aprilia             Italy      RS 125           125        15.0    12.0
# 3  Aprilia             Italy  Shiver 900           896        95.0    90.0
# 4  Aprilia             Italy  Tuono 1100          1077       175.0   121.0
#
#   Transmission_Type Drivetrain  Number_of_Seating  Price_(in_INR)  Year  \
# 0            Others      Chain                  2       1099000.0  2021
# 1            Others      Chain                  2       1199000.0  2021
# 2    6-speed manual      Chain                  2        449000.0  2022
# 3    6-speed manual     Others                  2       1399000.0  2022
# 4    6-speed manual     Others                  2       1999000.0  2022
#
#        Looks Body_Type      Engine_Type  Number_of_Cylinders
# ...

# %% [markdown]
# # EDA

# %%
year_counts = data['Year'].value_counts().sort_index()

plt.figure(figsize=(10, 6))
plt.plot(year_counts.index, year_counts.values, marker='o', linestyle='-', color='b')

plt.title("Motorcycle through years", fontweight='bold')
plt.xlabel("Year", fontweight='bold')
plt.ylabel("Number of Models", fontweight='bold')

plt.grid(True)
plt.show()

# %%
sns.set(style="whitegrid")

plt.figure(figsize=(10, 6))
sns.countplot(data=data, y='Country_of_Origin', palette='dark')
plt.title("Count of Motorcycles by Country", fontweight='bold')
plt.xlabel("Count", fontweight='bold')
plt.ylabel("Country", fontweight='bold')
plt.show()

# %%
top_models = data['Model'].value_counts().head(5)

# %%
explode = (0.1, 0, 0, 0, 0)

colors = ['#1A2F4B', '#28475C', '#2F8886', '#84C69B', '#00ADB5']
plt.figure(figsize=(8, 8))
_, _, autotexts = plt.pie(top_models, labels=top_models.index, autopct='', startangle=140, explode=explode, colors=colors)
plt.title("Top 5 Motorcycle Models", fontweight='bold')
plt.axis('equal')

for i, model_count in enumerate(top_models):
    autotexts[i].set_text(f'{model_count}')

legend_labels = top_models.index
plt.legend(legend_labels, title='Models', loc='best', bbox_to_anchor=(1, 1), prop={'weight':'bold'})

plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=data, x='Torque', color='#61677A')
plt.title("Distribution of Torque", fontweight='bold')
plt.xlabel("Torque", fontweight='bold')
plt.ylabel("Count", fontweight='bold')

plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=data, x='Horsepower', color='#5C469C')
plt.title("Distribution of Horsepower", fontweight='bold')
plt.xlabel("Horsepower", fontweight='bold')
plt.ylabel("Count", fontweight='bold')

plt.show()

# %%
plt.figure(figsize=(5, 5))
sns.scatterplot(data=data, x='Horsepower', y='Torque', c ='#B55400')
plt.title("Horsepower vs Torque", fontweight='bold')
plt.xlabel("Horsepower", fontweight='bold')
plt.ylabel("Torque", fontweight='bold')
plt.show()

# %%
seating_counts = data['Number_of_Seating'].value_counts()

colors = ['#0E1555', '#AF0404', '#F39422']
explode = (0.1, 0, 0)

plt.figure(figsize=(8, 8))
_, _, autotexts = plt.pie(seating_counts, labels=seating_counts.index, autopct='', startangle=140, explode=explode, colors=colors)
plt.title("Number of Seating in Motorcycles", fontweight='bold')
plt.axis('equal')

for i, count in enumerate(seating_counts):
    autotexts[i].set_text(f'{count}')

legend_labels = seating_counts.index
plt.legend(legend_labels, title='Seating Capacity', loc='best', bbox_to_anchor=(1, 1), prop={'weight':'bold'})

plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(data.isnull(),cmap='YlGnBu',)
plt.title('Missing Values Heatmap', fontweight='bold', fontsize=14)
plt.show()

# %%
price_ranges = [0, 500000, 1000000, 1500000, float('inf')]
price_labels = ['Low', 'Medium', 'High', 'Very High']

data['Price_Range'] = pd.cut(data['Price_(in_INR)'], bins=price_ranges, labels=price_labels)

heatmap_data = data.pivot_table(index='Price_Range', values=['Number_of_cc', 'Horsepower', "Torque"], aggfunc='mean')

plt.figure(figsize=(10, 6))
sns.heatmap(heatmap_data, cmap='PiYG', annot=True, fmt='.1f', cbar=True,linewidths=0.8)
plt.title("Price Range vs Features", fontweight='bold')
plt.xlabel("Features", fontweight='bold')
plt.ylabel("Price Range", fontweight='bold')

plt.show()

# %%
from matplotlib.ticker import ScalarFormatter

plt.figure(figsize=(12, 9))
ax = sns.histplot(data['Price_(in_INR)'], bins=20, kde=True, color='#1E5128')


ax.xaxis.set_major_formatter(ScalarFormatter(useMathText=True))
ax.ticklabel_format(axis='x', style='plain')

plt.title("Distribution of Motorcycle Prices", fontweight='bold')
plt.xlabel("Price", fontweight='bold')
plt.ylabel("Count", fontweight='bold')
plt.show()

# %%
from matplotlib.ticker import FuncFormatter

def price_formatter(x, pos):
    return f'₹{x:,.0f}'

plt.figure(figsize=(14, 10))

ax = sns.boxplot(data=data, x='Price_(in_INR)', y='Country_of_Origin', palette='rocket')

ax.xaxis.set_major_formatter(FuncFormatter(price_formatter))

plt.title("Price Distribution by Country", fontweight='bold')
plt.xlabel("Price (in INR)", fontweight='bold')
plt.ylabel("Country", fontweight='bold')

plt.show()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

def generate_word_cloud(data, column_name, title, colormap):
    text = ' '.join(data[column_name].astype(str))

    wordcloud = WordCloud(width=800, height=400, background_color='black', colormap=colormap, max_words=100).generate(text)

    plt.figure(figsize=(10, 6))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.title(title, fontsize=16, fontweight='bold')
    plt.axis('off')
    plt.show()

generate_word_cloud(data, 'Company', 'Word Cloud of Company Names','viridis')

# %%
generate_word_cloud(data, 'Country_of_Origin', 'Word Cloud of Country of Origin','cool')

# %%
generate_word_cloud(data, 'Model', 'Word Cloud of Motorcycle Models', 'plasma')
